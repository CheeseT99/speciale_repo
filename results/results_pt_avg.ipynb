# %% [markdown]
# # Prospect‑Theory Backtesting – Analysis Notebook
# This Jupyter notebook reproduces and extends the analysis from `results_pt_avg.py`.
#
# It:
# 1. Generates rolling Bayesian Model Averaging (BMA) forecasts and historical‐mean forecasts.
# 2. Runs Prospect‑Theory (PT) optimisations, a MVP benchmark, a Max‑Sharpe benchmark, and a naive 1/N portfolio.
# 3. Calculates **annualised Sharpe ratios** (monthly data ×√12).
# 4. Computes **average Certainty Equivalents (CE)** across the λ/γ grid for PT methods.
# 5. Builds and compares **cumulative net‑return paths** for each method.
# 6. Presents comparison tables:
#    * Strategy‑level metrics within each PT method
#    * Average cumulative‑return comparison across methods
#    * Same summary tables shown in the original script
#
# ---

# %%
# ---- Locate and add the 'functions' directory automatically -------------
import sys, pathlib, os

def add_functions_dir():
    here = pathlib.Path.cwd()          # start from current working dir
    for p in [here] + list(here.parents):
        candidate = p / "functions"
        if candidate.is_dir():
            sys.path.insert(0, str(candidate))
            print("✅  Added to sys.path:", candidate)
            return
    print("⚠️  'functions' folder not found – check your project structure")

add_functions_dir()
import prospect_optimizer as po
import evaluation as ev
# Out:
# ✅  Added to sys.path: c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo\functions

# %%
# --- User settings -------------------------------------------------
strategies      = ["conservative", "aggressive"]
lambda_values   = [1.99, 2.5]
gamma_values    = [0.12, 0.20]

reference_return = 1.02**(1/12)-1  # Monthly

start_date      = "1977-06-01"
end_date        = "2016-12-01"
date_tag        = f"{start_date}_{end_date}"
# %cd ..
parent_dir      = os.getcwd()
cache_dir       = "./bma_cache"
# Out:
# c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo

# %%
# --- Helper functions ---------------------------------------------
import numpy as np, pandas as pd
import matplotlib.pyplot as plt
def annualised_sharpe(ret_series, rf=0.0):
    """Annualises the Sharpe ratio for monthly data (ex‑ante rf)."""
    excess = ret_series - rf
    return excess.mean() / excess.std(ddof=1) * np.sqrt(12)

def mean_cumulative(results_dict):
    """Equal‑weight average cumulative net‑return path over all strategies."""
    cum_paths = [
        df["Compounded Returns"].rename(key)
        for key, df in results_dict.items()
    ]
    return pd.concat(cum_paths, axis=1).mean(axis=1)

# %%
# --- Run back‑tests ----------------------------------------------

print("⏳ Rolling BMA forecasts …")
bma_returns = po.rolling_bma_returns(
    parent_dir, n_predictors_to_use=2,
    start_date=start_date, end_date=end_date)

historical_returns = po.load_historical_returns(
    parent_dir, start_date, end_date)

# reference_series = po.load_risk_free_rate_from_factors(
#     parent_dir, start_date, end_date)
# reference_series = po.slice_reference(reference_series, start_date, end_date)

print("⏳ Back‑testing PT by BMA …")
results_bma = po.resultgenerator_bma(
    lambda_values, gamma_values, bma_returns,
    historical_returns, strategies, date_tag, cache_dir)

print("⏳ Back‑testing PT by Historical mean …")
results_hist = po.resultgenerator_historical_mean(
    lambda_values, gamma_values, historical_returns,
    strategies, date_tag)

print("⏳ Back‑testing MVP (benchmark) …")
results_mvp = po.resultgenerator_mvp(
    lambda_values, gamma_values, historical_returns,
    strategies, date_tag)

print("⏳ Back‑testing Max‑Sharpe on BMA …")
results_bma_ms = po.resultgenerator_bma_maxsharpe(
    lambda_values, gamma_values, bma_returns,
    historical_returns, strategies, date_tag)

print("⏳ Building naive equal‑weight portfolio …")
naive = po.naive_equal_weight_portfolio(
    historical_returns, start_date, end_date)
naive_key = f"conservative_{lambda_values[0]}_{gamma_values[0]}"
results_naive = {naive_key: naive}

test_assets_returns, factor_returns = po.load_test_assets_and_factors(
    parent_dir=parent_dir,
    historical_returns=historical_returns,
    start_date=start_date,
    end_date=end_date
)

results_dict_factor_model = po.resultgenerator_factor_model(
    lambda_values=lambda_values,
    gamma_values=gamma_values,
    test_assets_returns=test_assets_returns,
    factor_returns=factor_returns,
    reference_series=reference_return,
    strategies=strategies,
    date_tag=date_tag
)

results_dict_max_sharpe = po.resultgenerator_max_sharpe(
    lambda_values=lambda_values,
    gamma_values=gamma_values,
    historical_returns=historical_returns,
    strategies=strategies,
    date_tag=date_tag
)


results_by_method = {
    "PT BMA":            results_bma,
    "PT HistMean":       results_hist,
    "PT Factor Model":  results_dict_factor_model,
    "MVP":     results_mvp,
    "MaxSharpe BMA":     results_bma_ms,
    "MaxSharpe HistMean": results_dict_max_sharpe,
    "Naive 1/N":         results_naive,
}
# Out:
# ⏳ Rolling BMA forecasts …
# Index(['Date', 'Mkt-RF', 'SMB', 'CMA', 'PEAD', 'QMJ', 'MGMT', 'PERF', 'LIQ',
#        'IFCR'],
#       dtype='object')
# Index(['Date', 'dp', 'dy', 'ep', 'de', 'svar', 'ntis', 'tbl', 'lty', 'dfy'], dtype='object')
# Processing 1987-06
# Loading cached BMA initialization from: c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo\bma_cache2.0\bma_init_1987-06.pkl
# Loading cached BMA predictions from: c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo\bma_cache2.0\bma_pred_1987-06.pkl
# Processing 1987-07
# Loading cached BMA initialization from: c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo\bma_cache2.0\bma_init_1987-07.pkl
# Loading cached BMA predictions from: c:\Users\toros\OneDrive\Dokumenter\advanced_finance\speciale_repo\bma_cache2.0\bma_pred_1987-07.pkl
# Processing 1987-08
# ...

# %%
results_bma
import pandas as pd

# suppose `results` is your dict of strategies:
# {
#   'conservative_1.99_0.12':    <pandas DataFrame>,
#   'aggressive_1.99_0.12':      <pandas DataFrame>,
#   ...
# }

# grab the “conservative_1.99_0.12” DataFrame
df = results_bma['conservative_1.99_0.12']

# now you can work with it—e.g. show the first rows
print(df)

# or assign it to a variable for further analysis
conservative = df.copy()

df
# Out:
#             Portfolio Returns  Compounded Returns  \
# 1987-07-01           0.008558            1.008558
# 1987-08-01           0.016334            1.025032
# 1987-09-01           0.004113            1.029248
# 1987-10-01           0.008319            1.037811
# 1987-11-01          -0.017389            1.019764
# ...                       ...                 ...
# 2016-08-01           0.012141            7.122391
# 2016-09-01           0.000484            7.125840
# 2016-10-01          -0.018146            6.996534
# 2016-11-01           0.010312            7.068682
# 2016-12-01           0.020076            7.210591
#
#                                             Portfolio Weights  \
# 1987-07-01  [0.0401, 0.0, 0.0, 0.1259, 0.0, 0.4527, 0.2819...
# 1987-08-01  [0.0966, 0.0, -0.0, -0.0, 0.0, 0.5494, 0.2614,...
# 1987-09-01  [0.1016, -0.0, 0.0, -0.0, -0.0, 0.5535, 0.2589...
# 1987-10-01  [0.1331, -0.0, -0.0, -0.0, -0.0, 0.5427, 0.244...
# ...

# %%
results_by_method #For hver af metoderne skal vi regne prospect value for hver eneste aktualiseret return. 
results_by_method = {
    k: v for k, v in results_by_method.items()
    if "conservative_1.99_0.2" not in k
}

# %%
test_assets_returns

cumulative_returns = (1 + test_assets_returns).cumprod()

# Plot
plt.figure()
for asset in cumulative_returns.columns:
    plt.plot(cumulative_returns.index, cumulative_returns[asset], label=asset)
plt.xlabel("Date")
plt.ylabel("Cumulative Return (Growth of $1)")
plt.title("Cumulative Returns of Test Assets")
plt.legend()
plt.tight_layout()
plt.show()
test_assets_returns
# Out:
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\10694639.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
#             Mkt-RF     SMB     CMA      PEAD       QMJ      MGMT      PERF  \
# Date
# 1977-06-01  0.0471  0.0207 -0.0122  0.002542 -0.008333 -0.009977  0.010016
# 1977-07-01 -0.0169  0.0182  0.0001 -0.007776  0.009184  0.011125  0.003183
# 1977-08-01 -0.0175  0.0089 -0.0062  0.019276  0.030540 -0.006110  0.026611
# 1977-09-01 -0.0027  0.0156 -0.0084  0.010915  0.003504 -0.001179  0.017279
# 1977-10-01 -0.0438  0.0150 -0.0046 -0.008172  0.010512  0.008145  0.003757
# ...            ...     ...     ...       ...       ...       ...       ...
# 2016-08-01  0.0050  0.0172 -0.0039 -0.010773  0.001626  0.018547 -0.049411
# 2016-09-01  0.0025  0.0174 -0.0009  0.039229 -0.031290 -0.009430 -0.021728
# 2016-10-01 -0.0202 -0.0401  0.0024 -0.013634  0.027660  0.032443  0.020009
# ...

# %%
# Remove all 'conservative_1.99_0.2' keys from all methods in results_by_method
##for method in results_by_method:
 #   results_by_method[method] = {
 #       k: v for k, v in results_by_method[method].items() if 'conservative_1.99_0.2' not in k
 #   }

# %%
# --- Performance summary ------------------------------------------
summary_frames = []
for mname, rdict in results_by_method.items():
    s = po.summarize_backtest_results(rdict)
    # Replace monthly Sharpe with annualised version
    s["Sharpe Ratio"] = [annualised_sharpe(df["Portfolio Returns"]) for df in rdict.values()]
    
    s["Method"] = mname
    summary_frames.append(s.reset_index())
#conservative_1.99_0.
perf_df = pd.concat(summary_frames).set_index("Strategy_Key")
print("Strategy‑level performance (annualised SR):")
display(perf_df[["Method", "Sharpe Ratio", "Std Dev", "Mean Return","Final Wealth", "HHI", "Prospect Value"]])
#perf_df = perf_df.drop("conservative_1.99_0.2", axis=0)
# Out:
# Strategy‑level performance (annualised SR):
#                                     Method  Sharpe Ratio   Std Dev  \
# Strategy_Key
# aggressive_2.5_0.2                  PT BMA      1.195573  0.012642
# conservative_2.5_0.2                PT BMA      1.202901  0.012655
# aggressive_2.5_0.12                 PT BMA      1.253400  0.013180
# conservative_2.5_0.12               PT BMA      1.259536  0.013213
# aggressive_1.99_0.2                 PT BMA      1.403876  0.015165
# conservative_1.99_0.2               PT BMA      1.405223  0.015234
# aggressive_1.99_0.12                PT BMA      1.459246  0.016520
# conservative_1.99_0.12              PT BMA      1.460986  0.016615
# conservative_2.5_0.2           PT HistMean      1.224691  0.012539
# aggressive_2.5_0.12            PT HistMean      1.249584  0.012734
# aggressive_2.5_0.2             PT HistMean      1.335694  0.012621
# conservative_2.5_0.12          PT HistMean      1.307921  0.013017
# ...

# %%
comparison_df = po.compare_methods(results_by_method)
#comparison_df = comparison_df.drop("conservative_1.99_0.2", axis=0)

# %%
comparison_df = ev.add_certainty_equivalent_to_comparison_df(comparison_df, reference=reference_return)
comparison_df
# Out:
#                             Strategy  Lambda  Gamma  Mean Return   Std Dev  \
# Strategy_Key
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004756  0.010045
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004671  0.009241
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004271  0.008622
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005737  0.016520
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005931  0.016437
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005524  0.015314
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004756  0.010045
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004671  0.009241
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004271  0.008622
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005514  0.015165
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005871  0.016134
# ...

# %%
comparison_df
# Out:
#                             Strategy  Lambda  Gamma  Mean Return   Std Dev  \
# Strategy_Key
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004756  0.010045
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004671  0.009241
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004271  0.008622
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005737  0.016520
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005931  0.016437
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005524  0.015314
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004756  0.010045
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004671  0.009241
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004271  0.008622
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005514  0.015165
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005871  0.016134
# ...

# %%
comparison_df
# Out:
#                             Strategy  Lambda  Gamma  Mean Return   Std Dev  \
# Strategy_Key
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004756  0.010045
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004671  0.009241
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.004271  0.008622
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005737  0.016520
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005931  0.016437
# aggressive_1.99_0.12      aggressive    1.99   0.12     0.005524  0.015314
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004756  0.010045
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004671  0.009241
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.004271  0.008622
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005514  0.015165
# aggressive_1.99_0.2       aggressive    1.99   0.20     0.005871  0.016134
# ...

# %%
# --- Detailed PT method tables ------------------------------------
pt_methods = ["PT BMA", "PT HistMean", "PT Factor Model"]
for m in pt_methods:
    display(pd.DataFrame({
        "Final Wealth": comparison_df[comparison_df.Method == m]["Final Wealth"],
        
        
        "Max Drawdown": comparison_df[comparison_df.Method == m]["Max Drawdown"],
        "HHI": comparison_df[comparison_df.Method == m]["HHI"],
       "Sharpe Ratio": comparison_df[comparison_df.Method == m]["Sharpe Ratio"]*np.sqrt(12),
        "Mean Return": comparison_df[comparison_df.Method == m]["Mean Return"],
        "Std Dev": comparison_df[comparison_df.Method == m]["Std Dev"],
        
        
        "Certainty Equivalance": comparison_df[comparison_df.Method == m]["Certainty Equivalent"]*np.sqrt(12),
        "Prospect Value": comparison_df[comparison_df.Method == m]["Sum of Prospect Values"]    #   "HHI": comparison_df[comparison_df.Method == m]["HHI"],
    }).sort_values("Sharpe Ratio", ascending=False).style.set_caption(f"{m} – Strategy‑level Results"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_910b4">
#   <caption>PT BMA – Strategy‑level Results</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_910b4_level0_col0" class="col_heading level0 col0" >Final Wealth</th>
#       <th id="T_910b4_level0_col1" class="col_heading level0 col1" >Max Drawdown</th>
#       <th id="T_910b4_level0_col2" class="col_heading level0 col2" >HHI</th>
#       <th id="T_910b4_level0_col3" class="col_heading level0 col3" >Sharpe Ratio</th>
#       <th id="T_910b4_level0_col4" class="col_heading level0 col4" >Mean Return</th>
#       <th id="T_910b4_level0_col5" class="col_heading level0 col5" >Std Dev</th>
#       <th id="T_910b4_level0_col6" class="col_heading level0 col6" >Certainty Equivalance</th>
#       <th id="T_910b4_level0_col7" class="col_heading level0 col7" >Prospect Value</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Strategy_Key</th>
# ...

# %%
import numpy as np

pt_methods = ["PT BMA", "PT HistMean", "PT Factor Model"]

for m in pt_methods:
    # 1) slice & copy
    df = comparison_df[comparison_df.Method == m].copy()
    
    # 2) compute %‐series and annualize
    df["Cumulative Return (%)"]     = (df["Final Wealth"] - 1) * 100
    df["Mean Return (%)"]           = df["Mean Return"]       * 100
    df["Max Drawdown (%)"]          = df["Max Drawdown"]      * 100
    df["Sharpe Ratio"]              = df["Sharpe Ratio"]      * np.sqrt(12)
    df["Certainty Equivalence"]     = df["Certainty Equivalent"] * np.sqrt(12)
    df["Prospect Value"]            = df["Sum of Prospect Values"]
    
    # 3) pick/order columns
    df_out = df[[
        "Cumulative Return (%)",
        "Max Drawdown (%)",
        "HHI",
        "Sharpe Ratio",
        "Mean Return (%)",
        "Std Dev",
        "Certainty Equivalence",
        "Prospect Value"
    ]]
    
    # 4) reset index into a column and rename
    df_out = (
        df_out
        .reset_index()
        .rename(columns={"index": "Strategy Key"})
    )
    
    # 5) format that key: drop underscores, inject λ and γ
    df_out["Strategy_Key"] = df_out["Strategy_Key"].astype(str).str.replace(
        r"(\w+)_(\d+\.\d+)_(\d+\.\d+)",
        r"\1 \2$\\lambda$ \3$\\gamma$",
        regex=True
    )
    
    # 6) rename headers so “%” shows up as “\%”
    df_out.rename(columns={
        "Cumulative Return (%)": "Cumulative Return (\\%)",
        "Max Drawdown (%)":      "Max Drawdown (\\%)",
        "Mean Return (%)":       "Mean Return (\\%)"
    }, inplace=True)
    
    # 7) emit LaTeX (escape=False lets your \lambda/\gamma through)
    print(df_out.to_latex(
        index=False,
        float_format="%.4f",
        caption=f"{m} – Strategy-level Results",
        label=f"tab:{m.replace(' ', '_')}",
        escape=False
    ))
# Out:
# \begin{table}
# \caption{PT BMA – Strategy-level Results}
# \label{tab:PT_BMA}
# \begin{tabular}{lrrrrrrrr}
# \toprule
# Strategy_Key & Cumulative Return (\%) & Max Drawdown (\%) & HHI & Sharpe Ratio & Mean Return (\%) & Std Dev & Certainty Equivalence & Prospect Value \\
# \midrule
# aggressive 1.99$\lambda$ 0.12$\gamma$ & 622.0581 & 86.2093 & 0.3041 & 1.2029 & 0.5737 & 0.0165 & 0.0142 & 0.1749 \\
# aggressive 1.99$\lambda$ 0.2$\gamma$ & 572.6685 & 85.2006 & 0.2855 & 1.2595 & 0.5514 & 0.0152 & 0.0134 & 0.2787 \\
# aggressive 2.5$\lambda$ 0.12$\gamma$ & 540.5582 & 84.3089 & 0.2502 & 1.4052 & 0.5347 & 0.0132 & 0.0128 & -0.7419 \\
# aggressive 2.5$\lambda$ 0.2$\gamma$ & 538.7481 & 84.2340 & 0.2413 & 1.4610 & 0.5332 & 0.0126 & 0.0127 & -0.9835 \\
# conservative 1.99$\lambda$ 0.12$\gamma$ & 621.0591 & 86.2011 & 0.3049 & 1.1956 & 0.5734 & 0.0166 & 0.0141 & 0.1599 \\
# conservative 1.99$\lambda$ 0.2$\gamma$ & 571.9333 & 85.1287 & 0.2852 & 1.2534 & 0.5512 & 0.0152 & 0.0134 & 0.2787 \\
# ...

# %%
pt_methods = ["PT BMA", "PT HistMean", "PT Factor Model"]

for m in pt_methods:
    df = comparison_df[comparison_df.Method == m][
        ["Final Wealth", "Max Drawdown", "HHI", "Sharpe Ratio", 
         "Mean Return", "Std Dev", "Certainty Equivalent", "Prospect Value"]
    ].copy()

    # Scale annualized Sharpe and CE if necessary
    df["Sharpe Ratio"] = df["Sharpe Ratio"] * np.sqrt(12)
    df["Certainty Equivalent"] = df["Certainty Equivalent"] * np.sqrt(12)

    # Generate LaTeX table
    latex_table = df.to_latex(
        index=False,
        caption=f"{m} – Strategy‑level Results",
        label=f"tab:{m.replace(' ', '_').lower()}",
        float_format="%.2f",
        column_format="|" + "c|" * len(df.columns)
    )

    

    print(latex_table)
# Out:
# \begin{table}
# \caption{PT BMA – Strategy‑level Results}
# \label{tab:pt_bma}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \toprule
# Final Wealth & Max Drawdown & HHI & Sharpe Ratio & Mean Return & Std Dev & Certainty Equivalent & Prospect Value \\
# \midrule
# 7.22 & 0.86 & 0.30 & 1.20 & 0.01 & 0.02 & 0.01 & 0.00 \\
# 6.73 & 0.85 & 0.29 & 1.26 & 0.01 & 0.02 & 0.01 & 0.00 \\
# 6.41 & 0.84 & 0.25 & 1.41 & 0.01 & 0.01 & 0.01 & -0.00 \\
# 6.39 & 0.84 & 0.24 & 1.46 & 0.01 & 0.01 & 0.01 & -0.00 \\
# 7.21 & 0.86 & 0.30 & 1.20 & 0.01 & 0.02 & 0.01 & 0.00 \\
# 6.72 & 0.85 & 0.29 & 1.25 & 0.01 & 0.02 & 0.01 & 0.00 \\
# 6.42 & 0.84 & 0.25 & 1.40 & 0.01 & 0.01 & 0.01 & -0.00 \\
# 6.39 & 0.84 & 0.24 & 1.46 & 0.01 & 0.01 & 0.01 & -0.00 \\
# \bottomrule
# \end{tabular}
# \end{table}
#
# \begin{table}
# \caption{PT HistMean – Strategy‑level Results}
# \label{tab:pt_histmean}
# \begin{tabular}{|c|c|c|c|c|c|c|c|}
# \toprule
# ...

# %%
 #2. Build an aggregation dictionary, converting FW & MR to %:
agg_dict = {
    #**{m: (m, "mean") for m in metrics if m not in ["Final Wealth", "Mean Return"]},
    # now explicitly handle Final Wealth and Mean Return as percentages
    "Final Wealth (%)": ("Final Wealth", lambda x: x.mean() * 100),
    "Mean Return (%)": ("Mean Return", lambda x: x.mean() * 100),
    # annualize Sharpe & CE as before
    "Sharpe Ratio (ann.)": ("Sharpe Ratio", lambda x: x.mean() * np.sqrt(12)),
    "CE": ("Certainty Equivalent", lambda x: x.mean() * np.sqrt(12)),
    "Sum of Prospect Values": ("Sum of Prospect Values", "mean"),
    "Max Drawdown (%)": ("Max Drawdown", lambda x: x.mean()*100),
    "HHI": ("HHI", "mean"),
    "Std Dev": ("Std Dev", "mean"),
}

# 3. Group by Method and aggregate:
summary_df = (
    comparison_df
       .groupby("Method")
       .agg(**agg_dict)
       .loc[:, [
           "Final Wealth (%)",
           "Max Drawdown (%)",
           "HHI",
           "Sharpe Ratio (ann.)",
           "Mean Return (%)",
           "Std Dev",
           "CE",
           "Sum of Prospect Values"
       ]]
)

# 4. Pretty‐print with per‐column formatting
styled = (
    summary_df.style
      .format({
          "Final Wealth (%)": "{:.2f}\%",    # two decimals + % sign
          "Mean Return (%)": "{:.2f}\%",
          "Max Drawdown (%)": "{:.2f}\%",
          # keep the rest at four decimals
          **{c: "{:.4f}" for c in summary_df.columns if c not in ["Final Wealth (%)", "Mean Return (%)","Max Drawdown (%)"]}
      })
      .set_caption("Average Metrics by Method")
)
display(styled)

# And if you still need LaTeX:
latex = summary_df.to_latex(
    caption="Average Metrics by Method",
    label="tab:avg_metrics",
    float_format="%.42",   # note: LaTeX won’t show the % suffix automatically
    header=True,
    index=True,
    bold_rows=True,
)
print(latex)
# Out:
# <>:37: SyntaxWarning: invalid escape sequence '\%'
# <>:38: SyntaxWarning: invalid escape sequence '\%'
# <>:39: SyntaxWarning: invalid escape sequence '\%'
# <>:37: SyntaxWarning: invalid escape sequence '\%'
# <>:38: SyntaxWarning: invalid escape sequence '\%'
# <>:39: SyntaxWarning: invalid escape sequence '\%'
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\1956420829.py:37: SyntaxWarning: invalid escape sequence '\%'
#   "Final Wealth (%)": "{:.2f}\%",    # two decimals + % sign
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\1956420829.py:38: SyntaxWarning: invalid escape sequence '\%'
#   "Mean Return (%)": "{:.2f}\%",
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\1956420829.py:39: SyntaxWarning: invalid escape sequence '\%'
#   "Max Drawdown (%)": "{:.2f}\%",
# <style type="text/css">
# </style>
# <table id="T_1ac4c">
#   <caption>Average Metrics by Method</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
# --- Average cumulative net‑return comparison ---------------------
cum_net_df = pd.DataFrame({m: mean_cumulative(r) for m, r in results_by_method.items()})
display(cum_net_df.tail())  # show last few rows

final_wealth = cum_net_df.iloc[-1].rename("Final Wealth")
display(final_wealth.to_frame().T.style.set_caption("Final Wealth (average of strategies)") )
# Out:
#               PT BMA  PT HistMean  PT Factor Model       MVP  MaxSharpe BMA  \
# 2016-08-01  6.576636     6.513266         7.248419  5.033428       5.012654
# 2016-09-01  6.590992     6.410099         7.114185  5.026305       5.028169
# 2016-10-01  6.471832     6.458614         7.182776  5.060426       4.958626
# 2016-11-01  6.537673     6.596531         7.340202  5.236059       5.001940
# 2016-12-01  6.684866     6.688119         7.454260  5.269587       5.127604
#
#             MaxSharpe HistMean  Naive 1/N
# 2016-08-01            4.324972   5.857994
# 2016-09-01            4.269705   5.849703
# 2016-10-01            4.299415   5.889417
# 2016-11-01            4.410916   6.093842
# 2016-12-01            4.463257   6.132867
# <style type="text/css">
# </style>
# <table id="T_5919d">
#   <caption>Final Wealth (average of strategies)</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
# %matplotlib inline     
from matplotlib.ticker import FuncFormatter  
cum_net_df = pd.DataFrame({m: mean_cumulative(r) for m, r in results_by_method.items()})

ax = cum_net_df.plot(figsize=(10, 6))
ax.set_title("Average Cumulative Net Return", fontsize=14)
ax.set_xlabel("Date / Period")
ax.set_ylabel("Cumulative Net Return (%)")

# multiply each tick value by 100 just for display
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y*100:.0f}%'))

ax.legend(title="Method", loc="best")
ax.grid(True, linestyle="--", linewidth=0.5)
plt.tight_layout()

# %%
cum_net_df
# Out:
#               PT BMA  PT HistMean  PT Factor Model       MVP  MaxSharpe BMA  \
# 1987-06-01       NaN          NaN              NaN       NaN            NaN
# 1987-07-01  1.008585     1.014151         1.001640  1.008032       1.006951
# 1987-08-01  1.023302     1.016593         1.014360  1.005976       1.015455
# 1987-09-01  1.026305     1.023750         1.021786  1.013247       1.019058
# 1987-10-01  1.034942     0.999950         1.009757  0.999864       1.027419
# ...              ...          ...              ...       ...            ...
# 2016-08-01  6.576636     6.513266         7.248419  5.033428       5.012654
# 2016-09-01  6.590992     6.410099         7.114185  5.026305       5.028169
# 2016-10-01  6.471832     6.458614         7.182776  5.060426       4.958626
# 2016-11-01  6.537673     6.596531         7.340202  5.236059       5.001940
# 2016-12-01  6.684866     6.688119         7.454260  5.269587       5.127604
#
#             MaxSharpe HistMean  Naive 1/N
# ...

# %%
results_by_method
# Out:
# {'PT BMA': {'conservative_1.99_0.12':             Portfolio Returns  Compounded Returns  \
#   1987-07-01           0.008558            1.008558
#   1987-08-01           0.016334            1.025032
#   1987-09-01           0.004113            1.029248
#   1987-10-01           0.008319            1.037811
#   1987-11-01          -0.017389            1.019764
#   ...                       ...                 ...
#   2016-08-01           0.012141            7.122391
#   2016-09-01           0.000484            7.125840
#   2016-10-01          -0.018146            6.996534
#   2016-11-01           0.010312            7.068682
#   2016-12-01           0.020076            7.210591
#
#                                               Portfolio Weights  \
#   1987-07-01  [0.0401, 0.0, 0.0, 0.1259, 0.0, 0.4527, 0.2819...
#   1987-08-01  [0.0966, 0.0, -0.0, -0.0, 0.0, 0.5494, 0.2614,...
#   1987-09-01  [0.1016, -0.0, 0.0, -0.0, -0.0, 0.5535, 0.2589...
# ...

# %%
# --- Average Certainty Equivalents -------------------------------
reference_series = po.load_risk_free_rate_from_factors(parent_dir, start_date=start_date, end_date=end_date)


# Slice according to the selected date range
reference_series = po.slice_reference(reference_series, start_date, end_date)
ce_df_all = ev.compare_certainty_equivalents(results_by_method, reference_series)
ce_summary = ev.summarize_certainty_equivalents(ce_df_all)
display(ce_summary.style.set_caption("Average Certainty Equivalent by Method"))
# Out:
# <style type="text/css">
# </style>
# <table id="T_a9fec">
#   <caption>Average Certainty Equivalent by Method</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a9fec_level0_col0" class="col_heading level0 col0" >CE Sum</th>
#       <th id="T_a9fec_level0_col1" class="col_heading level0 col1" >CE Mean</th>
#       <th id="T_a9fec_level0_col2" class="col_heading level0 col2" >CE Std Dev</th>
#       <th id="T_a9fec_level0_col3" class="col_heading level0 col3" >CE Median</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Method</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9fec_level0_row0" class="row_heading level0 row0" >Naive 1/N</th>
#       <td id="T_a9fec_row0_col0" class="data row0 col0" >0.000721</td>
# ...

# %%
# ── 1  Run the PT Factor back-test (replace with your own generator) ─────────
print("⏳ Back-testing PT by Factor model …")
#results_factor = po.resultgenerator_factor(          # ← use your actual func
#    lambda_values, gamma_values,
#    #factor_returns,                 # e.g. po.load_factor_returns(...)
#    historical_returns,
#    strategies, date_tag)

# ── 2  Collect every method in one dict ──────────────────────────────────────
results_by_method = {
    "PT BMA":            results_bma,
    "PT HistMean":       results_hist,
    "PT Factor Model":         results_dict_factor_model,           # ← newly added
    "MVP":     results_mvp,
    "MaxSharpe HistMean": results_dict_max_sharpe,
    "MaxSharpe BMA":     results_bma_ms,
    "Naive 1/N":         results_naive,
}

# ── 3  Average cumulative net-return path per method ‐ and final wealth ─────
cum_net_df   = pd.DataFrame({m: mean_cumulative(r) for m, r in results_by_method.items()})
final_wealth = cum_net_df.iloc[-1].rename("Final Wealth")        # Series: index = method

# ── 4  Transposed table – each method in its own row ────────────────────────
final_wealth_tbl = final_wealth.to_frame(name="Final Wealth")    # already transposed
display(final_wealth_tbl.style.set_caption("Final Wealth (average of strategies) – transposed"))


# Annualised Sharpe (already in perf_df) – take mean across strategies
avg_sharpe = perf_df.groupby("Method")["Sharpe Ratio"].mean()

# Certainty Equivalent mean (already in ce_summary)
avg_ce = ce_summary["CE Mean"]

benchmark_df = pd.concat([final_wealth, avg_sharpe, avg_ce], axis=1)
benchmark_df.columns = ["Final Wealth", "Annualised Sharpe", "Average CE"]
benchmark_df = benchmark_df.loc[results_by_method.keys()]        # keep row order tidy
display(benchmark_df.style.set_caption("Benchmark metrics by method (transposed)"))
# Out:
# ⏳ Back-testing PT by Factor model …
# <style type="text/css">
# </style>
# <table id="T_f56a8">
#   <caption>Final Wealth (average of strategies) – transposed</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f56a8_level0_col0" class="col_heading level0 col0" >Final Wealth</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f56a8_level0_row0" class="row_heading level0 row0" >PT BMA</th>
#       <td id="T_f56a8_row0_col0" class="data row0 col0" >6.684866</td>
#     </tr>
#     <tr>
#       <th id="T_f56a8_level0_row1" class="row_heading level0 row1" >PT HistMean</th>
#       <td id="T_f56a8_row1_col0" class="data row1 col0" >6.688119</td>
#     </tr>
#     <tr>
#       <th id="T_f56a8_level0_row2" class="row_heading level0 row2" >PT Factor Model</th>
#       <td id="T_f56a8_row2_col0" class="data row2 col0" >7.454260</td>
#     </tr>
#     <tr>
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(10, 6))
for col in cum_net_df.columns:
    plt.plot(cum_net_df.index, cum_net_df[col], label=col)

# grab current axes
ax = plt.gca()

# titles & labels
ax.set_title("Average Cumulative Net Return", fontsize=14)
ax.set_xlabel("Date / Period")
ax.set_ylabel("Cumulative Net Return (%)")
first_date = cum_net_df.index.min()
last_date  = cum_net_df.index.max()
span       = last_date - first_date

# Extend the right-hand limit by 5% of the total time span
ax.set_xlim(first_date, last_date + span * 0.05)

# format y-axis ticks as percentages
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y*100:.0f}%'))

# legend with title and best location
ax.legend(title="Method", loc="best")

# light dashed gridlines
ax.grid(True, linestyle="--", linewidth=0.5)

# tighten up margins
plt.tight_layout()

# Save as PDF
plt.savefig("average_cumulative_net_return.pdf", format='pdf')

plt.show()

# %%
cum_net_df[["PT BMA", "PT HistMean", "PT Factor Model"]]
# Out:
#               PT BMA  PT HistMean  PT Factor Model
# 1987-06-01       NaN          NaN              NaN
# 1987-07-01  1.008585     1.014151         1.001640
# 1987-08-01  1.023302     1.016593         1.014360
# 1987-09-01  1.026305     1.023750         1.021786
# 1987-10-01  1.034942     0.999950         1.009757
# ...              ...          ...              ...
# 2016-08-01  6.576636     6.513266         7.248419
# 2016-09-01  6.590992     6.410099         7.114185
# 2016-10-01  6.471832     6.458614         7.182776
# 2016-11-01  6.537673     6.596531         7.340202
# 2016-12-01  6.684866     6.688119         7.454260
#
# [355 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(10, 6))

for col in cum_net_df[["PT BMA", "PT HistMean", "PT Factor Model"]].columns:
    plt.plot(cum_net_df.index, cum_net_df[col], label=col)

ax = plt.gca()

ax.set_title("Average Cumulative Net Return", fontsize=14)
ax.set_xlabel("Date / Period")
ax.set_ylabel("Cumulative Net Return (%)")

first_date = cum_net_df.index.min()
last_date  = cum_net_df.index.max()
span       = last_date - first_date

ax.set_xlim(first_date, last_date + span * 0.05)
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y*100:.0f}%'))
ax.legend(title="Method", loc="best")
ax.grid(True, linestyle="--", linewidth=0.5)

plt.tight_layout()

# save as PDF
plt.savefig("average_cumulative_net_return_pt.pdf",
            format="pdf",
            bbox_inches="tight")

plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate cumulative sum of Prospect Values per method
cum_prospect_df = pd.DataFrame({
    method: pd.concat(
        [df['Prospect Value'].cumsum() for df in results.values()], axis=1
    ).mean(axis=1)
    for method, results in results_by_method.items()
})

# Plot the cumulative sum of Prospect Values
fig, ax = plt.subplots(figsize=(12, 7))
for method in cum_prospect_df[["PT BMA", "PT HistMean", "PT Factor Model"]].columns:
    ax.plot(cum_prospect_df.index, cum_prospect_df[method], label=method)

# Lock x-limits to data range (with 5% right‐hand padding)
first_date = cum_prospect_df.index.min()
last_date  = cum_prospect_df.index.max()
span       = last_date - first_date
ax.set_xlim(first_date, last_date + span * 0.05)

# Labels and grid
ax.set_xlabel("Date")
ax.set_ylabel("Cumulative Prospect Value")
ax.legend(title="Method", loc="best")
ax.grid(True, linestyle='--', linewidth=0.5)

# Add a note at the bottom of the figure
fig.text(
    0.5,         # x-position (center)
    0.01,        # y-position (just above the bottom)
    "*Average over strategies", 
    ha='center', 
    va='bottom', 
    fontsize=10, 
    color='black'
)

plt.tight_layout(rect=[0, 0.03, 1, 1])  # leave space at the bottom for the note

# Save as PDF
plt.savefig("cumulative_prospect_value_ptmethods.pdf", format="pdf")

plt.show()

# %%
import numpy as np

pt_methods = ["PT BMA", "PT HistMean", "PT Factor Model"]

for m in pt_methods:
    # 1) slice & copy
    df = comparison_df[comparison_df.Method == m].copy()
    
    # 2) compute %‐series and annualize
    df["Cumulative Return (%)"]     = (df["Final Wealth"] - 1) * 100
    df["Mean Return (%)"]           = df["Mean Return"]       * 100
    df["Max Drawdown (%)"]          = df["Max Drawdown"]      * 100
    df["Sharpe Ratio"]              = df["Sharpe Ratio"]      * np.sqrt(12)
    df["Certainty Equivalence"]     = df["Certainty Equivalent"] * np.sqrt(12)
    df["Prospect Value"]            = df["Sum of Prospect Values"]
    
    # 3) pick/order columns
    df_out = df[[
        "Cumulative Return (%)",
        "Max Drawdown (%)",
        "HHI",
        "Sharpe Ratio",
        "Mean Return (%)",
        "Std Dev",
        "Certainty Equivalence",
        "Prospect Value"
    ]]
    
    # 4) reset index into a column and rename
    df_out = (
        df_out
        .reset_index()
        .rename(columns={"index": "Strategy Key"})
    )
    
    # 5) format that key: drop underscores, inject λ and γ
    df_out["Strategy_Key"] = df_out["Strategy_Key"].astype(str).str.replace(
        r"(\w+)_(\d+\.\d+)_(\d+\.\d+)",
        r"\1 \2$\\lambda$ \3$\\gamma$",
        regex=True
    )
    
    # 6) rename headers so “%” shows up as “\%”
    df_out.rename(columns={
        "Cumulative Return (%)": "Cumulative Return (\\%)",
        "Max Drawdown (%)":      "Max Drawdown (\\%)",
        "Mean Return (%)":       "Mean Return (\\%)"
    }, inplace=True)
    
    # 7) emit LaTeX (escape=False lets your \lambda/\gamma through)
    print(df_out.to_latex(
        index=False,
        float_format="%.4f",
        caption=f"{m} – Strategy-level Results",
        label=f"tab:{m.replace(' ', '_')}",
        escape=False
    ))
# Out:
# \begin{table}
# \caption{PT BMA – Strategy-level Results}
# \label{tab:PT_BMA}
# \begin{tabular}{lrrrrrrrr}
# \toprule
# Strategy_Key & Cumulative Return (\%) & Max Drawdown (\%) & HHI & Sharpe Ratio & Mean Return (\%) & Std Dev & Certainty Equivalence & Prospect Value \\
# \midrule
# aggressive 1.99$\lambda$ 0.12$\gamma$ & 622.0581 & 86.2093 & 0.3041 & 1.2029 & 0.5737 & 0.0165 & 0.0142 & 0.1749 \\
# aggressive 1.99$\lambda$ 0.2$\gamma$ & 572.6685 & 85.2006 & 0.2855 & 1.2595 & 0.5514 & 0.0152 & 0.0134 & 0.2787 \\
# aggressive 2.5$\lambda$ 0.12$\gamma$ & 540.5582 & 84.3089 & 0.2502 & 1.4052 & 0.5347 & 0.0132 & 0.0128 & -0.7419 \\
# aggressive 2.5$\lambda$ 0.2$\gamma$ & 538.7481 & 84.2340 & 0.2413 & 1.4610 & 0.5332 & 0.0126 & 0.0127 & -0.9835 \\
# conservative 1.99$\lambda$ 0.12$\gamma$ & 621.0591 & 86.2011 & 0.3049 & 1.1956 & 0.5734 & 0.0166 & 0.0141 & 0.1599 \\
# conservative 1.99$\lambda$ 0.2$\gamma$ & 571.9333 & 85.1287 & 0.2852 & 1.2534 & 0.5512 & 0.0152 & 0.0134 & 0.2787 \\
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib as mpl

# Optional: configure PGF to use your LaTeX fonts/preamble
mpl.use("pgf")
mpl.rcParams.update({
    "pgf.texsystem": "pdflatex",   # or "xelatex"/"lualatex"
    "font.family": "serif",
    "text.usetex": True,
    "pgf.rcfonts": False,
})

pt_methods = ["PT HistMean", "PT BMA", "PT Factor Model"]

for method in pt_methods:
    fig, ax = plt.subplots(figsize=(10, 6))

    # plot each strategy’s cumulative returns
    for strategy_name, strategy_df in results_by_method[method].items():
        cumulative_returns = (1 + strategy_df['Portfolio Returns']).cumprod()
        ax.plot(cumulative_returns.index,
                cumulative_returns,
                label=strategy_name)

    # axes labels and formatting
    ax.set_xlabel("Date")
    ax.set_ylabel("Cumulative Net Return (%)")
    ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y*100:.0f}%'))

    # extend x-axis by 5%
    first_date = cumulative_returns.index.min()
    last_date  = cumulative_returns.index.max()
    span       = last_date - first_date
    ax.set_xlim(first_date, last_date + span * 0.05)

    # legend & grid
    ax.legend(title="Strategy", loc="best")
    ax.grid(True, linestyle="--", linewidth=0.5)

    fig.tight_layout()

    # filenames
    base = method.replace(" ", "_")
    pdf_fname = f"cum_returns_{base}.pdf"
    pgf_fname = f"cum_returns_{base}.pgf"

    # save a vector PDF (for general use)
    fig.savefig(pdf_fname,
                format="pdf",
                bbox_inches="tight")

    # save a PGF (for direct \\input in LaTeX)
    fig.savefig(pgf_fname,
                bbox_inches="tight")

    plt.show()
    print(f"Saved: {pdf_fname}  and  {pgf_fname}")
# Out:
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\3992098655.py:57: UserWarning: FigureCanvasPgf is non-interactive, and thus cannot be shown
#   plt.show()
# Saved: cum_returns_PT_HistMean.pdf  and  cum_returns_PT_HistMean.pgf
# Saved: cum_returns_PT_BMA.pdf  and  cum_returns_PT_BMA.pgf
# Saved: cum_returns_PT_Factor_Model.pdf  and  cum_returns_PT_Factor_Model.pgf

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
pt_methods = ["PT HistMean", "PT BMA", "PT Factor Model"]

for method in pt_methods:
    fig, ax = plt.subplots(figsize=(10, 6))

    for strategy_name, strategy_df in results_by_method[method].items():
        cumulative_pt_values = strategy_df['Prospect Value'].cumsum()
        ax.plot(cumulative_pt_values.index,
                cumulative_pt_values,
                label=strategy_name)

    # Extend x‐axis by 5%
    first_date = cumulative_pt_values.index.min()
    last_date  = cumulative_pt_values.index.max()
    span       = last_date - first_date
    ax.set_xlim(first_date, last_date + span * 0.05)

    # Labels, legend, grid
    ax.set_xlabel("Date")
    ax.set_ylabel("Cumulative Prospect Theory Value")
    ax.legend(title="Strategy", loc="best")
    ax.grid(True, linestyle="--", linewidth=0.5)
    fig.tight_layout()

    # SAVE AT 1200 DPI
    
    fig.savefig(f"cum_PT_{method.replace(' ', '_')}.pdf",
            format="pdf",
            bbox_inches="tight") # crops extra whitespace

    plt.show()
    print(f"Saved high-def plot: {"yo"}")
# Out:
# C:\Users\toros\AppData\Local\Temp\ipykernel_23548\992472626.py:33: UserWarning: FigureCanvasPgf is non-interactive, and thus cannot be shown
#   plt.show()
# Saved high-def plot: yo
# Saved high-def plot: yo
# Saved high-def plot: yo

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

plt.figure(figsize=(10, 6))
for col in cum_net_df.columns:
    plt.plot(cum_net_df.index, cum_net_df[col], label=col)

ax = plt.gca()
#ax.set_title("Average Cumulative Net Return", fontsize=14)
ax.set_xlabel("Date / Period")
ax.set_ylabel("Cumulative Net Return (%)")
first_date = cumulative_pt_values.index.min()
last_date  = cumulative_pt_values.index.max()
span       = last_date - first_date
ax.set_xlim(first_date, last_date + span * 0.05)
ax.yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y*100:.0f}%'))
ax.legend(title="Method", loc="best")
ax.grid(True, linestyle="--", linewidth=0.5)

plt.tight_layout()

# Save as PDF:
plt.savefig("average_cumulative_net_return.pdf", format="pdf", bbox_inches="tight")

# (Optional) display in notebook
plt.show()

# %%
import matplotlib.pyplot as plt

# Calculate cumulative sum of Prospect Values per method
cum_prospect_df = pd.DataFrame({
    method: pd.concat(
        [df['Prospect Value'].cumsum() for df in results.values()], axis=1
    ).mean(axis=1)
    for method, results in results_by_method.items()
})

# Plot the cumulative sum of Prospect Values
fig, ax = plt.subplots(figsize=(12, 7))
for method in cum_prospect_df.columns:
    ax.plot(cum_prospect_df.index, cum_prospect_df[method], label=method)

# Lock x-limits to data range (with 5% right‐hand padding)
first_date = cum_prospect_df.index.min()
last_date  = cum_prospect_df.index.max()
span       = last_date - first_date
ax.set_xlim(first_date, last_date + span * 0.05)

# Labels and grid
ax.set_xlabel("Date")
ax.set_ylabel("Cumulative Prospect Value")
ax.legend(title="Method", loc="best")
ax.grid(True, linestyle='--', linewidth=0.5)

# Add a note at the bottom of the figure
fig.text(
    0.5,         # x-position (center)
    0.01,        # y-position (just above the bottom)
    "*Average over strategies", 
    ha='center', 
    va='bottom', 
    fontsize=10, 
    color='black'
)

plt.tight_layout(rect=[0, 0.03, 1, 1])  # leave space at the bottom for the note

# Save as PDF
plt.savefig("cumulative_prospect_value.pdf", format="pdf")

plt.show()

# %%
# Calculate cumulative sum of Prospect Values per method
cum_prospect_df = pd.DataFrame({
    method: pd.concat(
        [df['Prospect Value'] for df in results.values()], axis=1
    ).mean(axis=1)
    for method, results in results_by_method.items()
})

# Plot the cumulative sum of Prospect Values
plt.figure(figsize=(12, 7))
for method in cum_prospect_df.columns:
    plt.plot(cum_prospect_df.index, cum_prospect_df[method], label=method)

plt.title("Cumulative Prospect Value (average across strategies)")
plt.xlabel("Date")
plt.ylabel("Cumulative Prospect Value")
plt.legend(title="Method")
plt.grid(True, linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

# %%
#Graf over estimation accuracy.
