# %%
import pandas as pd
import os

# %%
# Pathing
parent_dir = os.path.dirname(os.getcwd())
csv_path = os.path.join(parent_dir+'/data/data_1st_BMA.csv')

# %%
# Read csv 
df = pd.read_csv(csv_path, index_col = 'date')
df = df.drop(columns=['month','month:1','month:2'])
print(df.columns)
df.head(10)
# Out:
# Index(['permno', 'ret', 'shrout', 'altprc', 'exchcd', 'siccd', 'mktcap',
#        'mktcap_lag', 'exchange', 'industry', 'ret_excess', 'gvkey', 'dp', 'dy',
#        'ep', 'de', 'svar', 'bm', 'ntis', 'tbl', 'lty', 'ltr', 'tms', 'dfy',
#        'infl', 'mkt_excess', 'smb', 'hml', 'rf'],
#       dtype='object')
#                      permno       ret     shrout  altprc  exchcd  siccd  \
# date
# 1993-03-31T00:00:00   10028 -0.100000  5626000.0  1.1250       2   5094
# 1993-04-30T00:00:00   10028  0.388889  5626000.0  1.5625       2   5094
# 1993-05-28T00:00:00   10028  0.200000  5626000.0  1.8750       2   5094
# 1993-06-30T00:00:00   10028 -0.133333  5566000.0 -1.6250       2   5094
# 1993-07-30T00:00:00   10028  0.192308  5566000.0  1.9375       2   5094
# 1993-08-31T00:00:00   10028 -0.032258  5566000.0  1.8750       2   5094
# 1993-09-30T00:00:00   10028 -0.066667  5566000.0  1.7500       2   5094
# 1993-10-29T00:00:00   10028  0.250000  5566000.0  2.1875       2   5094
# ...

# %%
df.shape
# Out:
# (3326353, 29)

# %%
df.tail(20)
# Out:
#                      permno       ret      shrout  altprc  exchcd  siccd  \
# date
# 2002-04-30T00:00:00   86170 -0.016667   2298000.0   2.950       2   8712
# 2002-05-31T00:00:00   86170 -0.118644   2298000.0   2.600       2   8712
# 2002-06-28T00:00:00   86170 -0.144231   2298000.0  -2.225       2   8712
# 2002-07-31T00:00:00   86170 -0.168539   2298000.0   1.850       2   8712
# 2002-08-30T00:00:00   86170  0.091892   2370000.0   2.020       2   8712
# 2002-09-30T00:00:00   86170  0.039604   2369000.0  -2.100       2   8712
# 2002-10-31T00:00:00   86170 -0.119048   2369000.0  -1.850       2   8712
# 2002-11-29T00:00:00   86170  0.351351   2369000.0  -2.500       2   8712
# 2002-12-31T00:00:00   86170  0.040000   2403000.0  -2.600       2   8712
# 2003-01-31T00:00:00   86170 -0.153846   2403000.0  -2.200       2   8712
# 2003-02-28T00:00:00   86170 -0.011364   2403000.0  -2.175       2   8712
# 2003-03-31T00:00:00   86170 -0.085057   2476000.0  -1.990       2   8712
# ...
